# %%
from pyspark.sql.types import StructType, StructField, StringType, ArrayType

# %%
filename = './test_data/events.json'

df = spark.read.option("multiline","true").json(filename)
df.printSchema()
df.show()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- results: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- term: string (nullable = true)
#  |-- transaction_id: string (nullable = true)
#  |-- type: string (nullable = true)
#
# +------+--------------------+-----------+--------------------+--------------+
# |    id|             results|       term|      transaction_id|          type|
# +------+--------------------+-----------+--------------------+--------------+
# |  null|                null|      omnis|9e4bdbef-86fe-4ac...|        SEARCH|
# |  null|[X00034, X00084, ...|       null|9e4bdbef-86fe-4ac...|SEARCH_RESULTS|
# |X00022|                null|       null|9e4bdbef-86fe-4ac...|   REPORT_VIEW|
# |X00084|                null|       null|9e4bdbef-86fe-4ac...|   REPORT_VIEW|
# |  null|                null|      quasi|067bf59a-2f53-459...|        SEARCH|
# |  null|[X00042, X00031, ...|       null|067bf59a-2f53-459...|SEARCH_RESULTS|
# |  null|                null|   sapiente|e0bf0ee2-3b0a-409...|        SEARCH|
# |  null|                  []|       null|e0bf0ee2-3b0a-409...|SEARCH_RESULTS|
# |  null|                null|  molestias|507e386e-d29a-406...|        SEARCH|
# |  null|            [X00097]|       null|507e386e-d29a-406...|SEARCH_RESULTS|
# |  null|                null|         ex|029c1fe7-722a-45f...|        SEARCH|
# |  null|                null|      porro|f92a19c9-7918-40b...|        SEARCH|
# |  null|[X00087, X00030, ...|       null|f92a19c9-7918-40b...|SEARCH_RESULTS|
# |  null|                null|     libero|6d030326-b720-433...|        SEARCH|
# |  null|                null|         ad|418ee440-d224-4d8...|        SEARCH|
# |  null|    [X00036, X00044]|       null|418ee440-d224-4d8...|SEARCH_RESULTS|
# |  null|                null|repellendus|3344a027-5455-496...|        SEARCH|
# |  null|                null|         at|221a1f34-a894-443...|        SEARCH|
# |  null|    [X00027, X00030]|       null|221a1f34-a894-443...|SEARCH_RESULTS|
# |X00030|                null|       null|221a1f34-a894-443...|   REPORT_VIEW|
# +------+--------------------+-----------+--------------------+--------------+
# only showing top 20 rows

# %%
event_schema = StructType(
        [
            StructField("id", StringType(), True),
            StructField("results", ArrayType(StringType(), True), True),
            StructField("term", StringType(), True),
            StructField("transaction_id", StringType(), True),
            StructField("type", StringType(), True),
        ]
    )

group_schema = StructType(
        [
            StructField("t_id", StringType(), True),
            StructField("events", ArrayType(event_schema, True), True),
        ]
    )

# %%
grouped = df.rdd.groupBy(lambda row: row['transaction_id']).mapValues(list)

def mapper(group):
    (t_id, rows) = group
    return (t_id, rows)

mapped = grouped.map(mapper)

res = mapped.collect()

print(type(res[0][1]))

print(res)

for t_id, group in grouped.collect():
    print(t_id)
    spark.createDataFrame(data=group, schema=event_schema).show()
# Out:
# <class 'list'>
# [('9e4bdbef-86fe-4ace-aa61-d29a64bbb5f4', [Row(id=None, results=None, term='omnis', transaction_id='9e4bdbef-86fe-4ace-aa61-d29a64bbb5f4', type='SEARCH'), Row(id=None, results=['X00034', 'X00084', 'X00009', 'X00071'], term=None, transaction_id='9e4bdbef-86fe-4ace-aa61-d29a64bbb5f4', type='SEARCH_RESULTS'), Row(id='X00022', results=None, term=None, transaction_id='9e4bdbef-86fe-4ace-aa61-d29a64bbb5f4', type='REPORT_VIEW'), Row(id='X00084', results=None, term=None, transaction_id='9e4bdbef-86fe-4ace-aa61-d29a64bbb5f4', type='REPORT_VIEW')]), ('067bf59a-2f53-459b-8ad0-2cb4a9639519', [Row(id=None, results=None, term='quasi', transaction_id='067bf59a-2f53-459b-8ad0-2cb4a9639519', type='SEARCH'), Row(id=None, results=['X00042', 'X00031', 'X00095'], term=None, transaction_id='067bf59a-2f53-459b-8ad0-2cb4a9639519', type='SEARCH_RESULTS')]), ('e0bf0ee2-3b0a-4095-9483-28aecd5e1437', [Row(id=None, results=None, term='sapiente', transaction_id='e0bf0ee2-3b0a-4095-9483-28aecd5e1437', type='SEARCH'), Row(id=None, results=[], term=None, transaction_id='e0bf0ee2-3b0a-4095-9483-28aecd5e1437', type='SEARCH_RESULTS')]), ('507e386e-d29a-4063-9621-d51dc91063cf', [Row(id=None, results=None, term='molestias', transaction_id='507e386e-d29a-4063-9621-d51dc91063cf', type='SEARCH'), Row(id=None, results=['X00097'], term=None, transaction_id='507e386e-d29a-4063-9621-d51dc91063cf', type='SEARCH_RESULTS')]), ('029c1fe7-722a-45f3-86f8-a88d57057567', [Row(id=None, results=None, term='ex', transaction_id='029c1fe7-722a-45f3-86f8-a88d57057567', type='SEARCH')]), ('f92a19c9-7918-40b1-9cbd-0d066b115326', [Row(id=None, results=None, term='porro', transaction_id='f92a19c9-7918-40b1-9cbd-0d066b115326', type='SEARCH'), Row(id=None, results=['X00087', 'X00030', 'X00045'], term=None, transaction_id='f92a19c9-7918-40b1-9cbd-0d066b115326', type='SEARCH_RESULTS')]), ('6d030326-b720-433c-8e96-03b7a3f3cf15', [Row(id=None, results=None, term='libero', transaction_id='6d030326-b720-433c-8e96-03b7a3f3cf15', type='SEARCH')]), ('418ee440-d224-4d88-94b6-5aa9ec28dc73', [Row(id=None, results=None, term='ad', transaction_id='418ee440-d224-4d88-94b6-5aa9ec28dc73', type='SEARCH'), Row(id=None, results=['X00036', 'X00044'], term=None, transaction_id='418ee440-d224-4d88-94b6-5aa9ec28dc73', type='SEARCH_RESULTS')]), ('3344a027-5455-496d-9ec6-b149cadbe86b', [Row(id=None, results=None, term='repellendus', transaction_id='3344a027-5455-496d-9ec6-b149cadbe86b', type='SEARCH')]), ('221a1f34-a894-4438-92b5-46e0b88d6217', [Row(id=None, results=None, term='at', transaction_id='221a1f34-a894-4438-92b5-46e0b88d6217', type='SEARCH'), Row(id=None, results=['X00027', 'X00030'], term=None, transaction_id='221a1f34-a894-4438-92b5-46e0b88d6217', type='SEARCH_RESULTS'), Row(id='X00030', results=None, term=None, transaction_id='221a1f34-a894-4438-92b5-46e0b88d6217', type='REPORT_VIEW'), Row(id='X00088', results=None, term=None, transaction_id='221a1f34-a894-4438-92b5-46e0b88d6217', type='REPORT_VIEW'), Row(id='X00027', results=None, term=None, transaction_id='221a1f34-a894-4438-92b5-46e0b88d6217', type='REPORT_VIEW')]), ('93827d0b-ae5e-4e0f-8ab7-389031d37c11', [Row(id=None, results=None, term='ducimus', transaction_id='93827d0b-ae5e-4e0f-8ab7-389031d37c11', type='SEARCH')]), ('0692d85d-8699-4954-a768-dd438534101c', [Row(id=None, results=None, term='eos', transaction_id='0692d85d-8699-4954-a768-dd438534101c', type='SEARCH')]), ('fe91129b-fcc4-4529-ad1d-4151fa856730', [Row(id=None, results=None, term='consequatur', transaction_id='fe91129b-fcc4-4529-ad1d-4151fa856730', type='SEARCH')]), ('9f167a48-bbbc-4946-a84c-7dee9a47d6a7', [Row(id=None, results=None, term='dignissimos', transaction_id='9f167a48-bbbc-4946-a84c-7dee9a47d6a7', type='SEARCH'), Row(id=None, results=['X00073', 'X00055'], term=None, transaction_id='9f167a48-bbbc-4946-a84c-7dee9a47d6a7', type='SEARCH_RESULTS'), Row(id='X00076', results=None, term=None, transaction_id='9f167a48-bbbc-4946-a84c-7dee9a47d6a7', type='REPORT_VIEW'), Row(id='X00055', ...
# 9e4bdbef-86fe-4ace-aa61-d29a64bbb5f4
# +------+--------------------+-----+--------------------+--------------+
# |    id|             results| term|      transaction_id|          type|
# +------+--------------------+-----+--------------------+--------------+
# |  null|                null|omnis|9e4bdbef-86fe-4ac...|        SEARCH|
# |  null|[X00034, X00084, ...| null|9e4bdbef-86fe-4ac...|SEARCH_RESULTS|
# |X00022|                null| null|9e4bdbef-86fe-4ac...|   REPORT_VIEW|
# |X00084|                null| null|9e4bdbef-86fe-4ac...|   REPORT_VIEW|
# +------+--------------------+-----+--------------------+--------------+
#
# 067bf59a-2f53-459b-8ad0-2cb4a9639519
# +----+--------------------+-----+--------------------+--------------+
# |  id|             results| term|      transaction_id|          type|
# +----+--------------------+-----+--------------------+--------------+
# |null|                null|quasi|067bf59a-2f53-459...|        SEARCH|
# |null|[X00042, X00031, ...| null|067bf59a-2f53-459...|SEARCH_RESULTS|
# +----+--------------------+-----+--------------------+--------------+
#
# e0bf0ee2-3b0a-4095-9483-28aecd5e1437
# +----+-------+--------+--------------------+--------------+
# |  id|results|    term|      transaction_id|          type|
# +----+-------+--------+--------------------+--------------+
# |null|   null|sapiente|e0bf0ee2-3b0a-409...|        SEARCH|
# |null|     []|    null|e0bf0ee2-3b0a-409...|SEARCH_RESULTS|
# +----+-------+--------+--------------------+--------------+
#
# 507e386e-d29a-4063-9621-d51dc91063cf
# +----+--------+---------+--------------------+--------------+
# |  id| results|     term|      transaction_id|          type|
# +----+--------+---------+--------------------+--------------+
# |null|    null|molestias|507e386e-d29a-406...|        SEARCH|
# |null|[X00097]|     null|507e386e-d29a-406...|SEARCH_RESULTS|
# +----+--------+---------+--------------------+--------------+
#
# 029c1fe7-722a-45f3-86f8-a88d57057567
# +----+-------+----+--------------------+------+
# |  id|results|term|      transaction_id|  type|
# +----+-------+----+--------------------+------+
# |null|   null|  ex|029c1fe7-722a-45f...|SEARCH|
# +----+-------+----+--------------------+------+
#
# f92a19c9-7918-40b1-9cbd-0d066b115326
# +----+--------------------+-----+--------------------+--------------+
# |  id|             results| term|      transaction_id|          type|
# +----+--------------------+-----+--------------------+--------------+
# |null|                null|porro|f92a19c9-7918-40b...|        SEARCH|
# |null|[X00087, X00030, ...| null|f92a19c9-7918-40b...|SEARCH_RESULTS|
# +----+--------------------+-----+--------------------+--------------+
#
# 6d030326-b720-433c-8e96-03b7a3f3cf15
# +----+-------+------+--------------------+------+
# |  id|results|  term|      transaction_id|  type|
# +----+-------+------+--------------------+------+
# |null|   null|libero|6d030326-b720-433...|SEARCH|
# +----+-------+------+--------------------+------+
#
# 418ee440-d224-4d88-94b6-5aa9ec28dc73
# +----+----------------+----+--------------------+--------------+
# |  id|         results|term|      transaction_id|          type|
# +----+----------------+----+--------------------+--------------+
# |null|            null|  ad|418ee440-d224-4d8...|        SEARCH|
# |null|[X00036, X00044]|null|418ee440-d224-4d8...|SEARCH_RESULTS|
# +----+----------------+----+--------------------+--------------+
#
# 3344a027-5455-496d-9ec6-b149cadbe86b
# +----+-------+-----------+--------------------+------+
# |  id|results|       term|      transaction_id|  type|
# +----+-------+-----------+--------------------+------+
# |null|   null|repellendus|3344a027-5455-496...|SEARCH|
# +----+-------+-----------+--------------------+------+
#
# 221a1f34-a894-4438-92b5-46e0b88d6217
# +------+----------------+----+--------------------+--------------+
# |    id|         results|term|      transaction_id|          type|
# +------+----------------+----+--------------------+--------------+
# |  null|            null|  at|221a1f34-a894-443...|        SEARCH|
# |  null|[X00027, X00030]|null|221a1f34-a894-443...|SEARCH_RESULTS|
# |X00030|            null|null|221a1f34-a894-443...|   REPORT_VIEW|
# |X00088|            null|null|221a1f34-a894-443...|   REPORT_VIEW|
# |X00027|            null|null|221a1f34-a894-443...|   REPORT_VIEW|
# +------+----------------+----+--------------------+--------------+
#
# 93827d0b-ae5e-4e0f-8ab7-389031d37c11
# +----+-------+-------+--------------------+------+
# |  id|results|   term|      transaction_id|  type|
# +----+-------+-------+--------------------+------+
# |null|   null|ducimus|93827d0b-ae5e-4e0...|SEARCH|
# +----+-------+-------+--------------------+------+
#
# 0692d85d-8699-4954-a768-dd438534101c
# +----+-------+----+--------------------+------+
# |  id|results|term|      transaction_id|  type|
# +----+-------+----+--------------------+------+
# |null|   null| eos|0692d85d-8699-495...|SEARCH|
# +----+-------+----+--------------------+------+
#
# fe91129b-fcc4-4529-ad1d-4151fa856730
# +----+-------+-----------+--------------------+------+
# |  id|results|       term|      transaction_id|  type|
# +----+-------+-----------+--------------------+------+
# |null|   null|consequatur|fe91129b-fcc4-452...|SEARCH|
# +----+-------+-----------+--------------------+------+
#
# 9f167a48-bbbc-4946-a84c-7dee9a47d6a7
# +------+----------------+-----------+--------------------+--------------+
# |    id|         results|       term|      transaction_id|          type|
# +------+----------------+-----------+--------------------+--------------+
# |  null|            null|dignissimos|9f167a48-bbbc-494...|        SEARCH|
# |  null|[X00073, X00055]|       null|9f167a48-bbbc-494...|SEARCH_RESULTS|
# |X00076|            null|       null|9f167a48-bbbc-494...|   REPORT_VIEW|
# |X00055|            null|       null|9f167a48-bbbc-494...|   REPORT_VIEW|
# |X00055|            null|       null|9f167a48-bbbc-494...|   REPORT_VIEW|
# +------+----------------+-----------+--------------------+--------------+
#
# 3abc6ca7-5846-48e3-bd10-76ca1f529c56
# +------+--------------------+----+--------------------+--------------+
# |    id|             results|term|      transaction_id|          type|
# +------+--------------------+----+--------------------+--------------+
# |  null|                null|illo|3abc6ca7-5846-48e...|        SEARCH|
# |  null|[X00030, X00021, ...|null|3abc6ca7-5846-48e...|SEARCH_RESULTS|
# |X00009|                null|null|3abc6ca7-5846-48e...|   REPORT_VIEW|
# |X00049|                null|null|3abc6ca7-5846-48e...|   REPORT_VIEW|
# |X00030|                null|null|3abc6ca7-5846-48e...|   REPORT_VIEW|
# +------+--------------------+----+--------------------+--------------+
#
# d288b607-8527-4759-9b4f-c870795d1430
# +----+--------+------------+--------------------+--------------+
# |  id| results|        term|      transaction_id|          type|
# +----+--------+------------+--------------------+--------------+
# |null|    null|consequuntur|d288b607-8527-475...|        SEARCH|
# |null|[X00020]|        null|d288b607-8527-475...|SEARCH_RESULTS|
# +----+--------+------------+--------------------+--------------+
#
# 5806d72b-890d-49f7-8034-b4808c68e0d1
# +----+-------+-------+--------------------+------+
# |  id|results|   term|      transaction_id|  type|
# +----+-------+-------+--------------------+------+
# |null|   null|nostrum|5806d72b-890d-49f...|SEARCH|
# +----+-------+-------+--------------------+------+
#
# cb418946-7d88-4da7-befc-67d3af9fc387
# +----+--------------------+-----------+--------------------+--------------+
# |  id|             results|       term|      transaction_id|          type|
# +----+--------------------+-----------+--------------------+--------------+
# |null|                null|consectetur|cb418946-7d88-4da...|        SEARCH|
# |null|[X00011, X00082, ...|       null|cb418946-7d88-4da...|SEARCH_RESULTS|
# +----+--------------------+-----------+--------------------+--------------+
#
# 98b52599-7abc-46a3-b26b-76da28b67d8f
# +----+-------+----+--------------------+------+
# |  id|results|term|      transaction_id|  type|
# +----+-------+----+--------------------+------+
# |null|   null|odit|98b52599-7abc-46a...|SEARCH|
# +----+-------+----+--------------------+------+
#
# 6fe2b89f-efae-4f28-8691-9fab949a0550
# +----+----------------+----+--------------------+--------------+
# |  id|         results|term|      transaction_id|          type|
# +----+----------------+----+--------------------+--------------+
# |null|            null|quas|6fe2b89f-efae-4f2...|        SEARCH|
# |null|[X00064, X00026]|null|6fe2b89f-efae-4f2...|SEARCH_RESULTS|
# +----+----------------+----+--------------------+--------------+
#
# ff73e725-af85-469c-a4a7-b9695edd0491
# +----+-------+-----+--------------------+------+
# |  id|results| term|      transaction_id|  type|
# +----+-------+-----+--------------------+------+
# |null|   null|ullam|ff73e725-af85-469...|SEARCH|
# +----+-------+-----+--------------------+------+
#
# 55d156cc-3c62-4ab1-b997-415f96f0c681
# +------+-------+-----------+--------------------+--------------+
# |    id|results|       term|      transaction_id|          type|
# +------+-------+-----------+--------------------+--------------+
# |  null|   null|dignissimos|55d156cc-3c62-4ab...|        SEARCH|
# |  null|     []|       null|55d156cc-3c62-4ab...|SEARCH_RESULTS|
# |X00048|   null|       null|55d156cc-3c62-4ab...|   REPORT_VIEW|
# |X00030|   null|       null|55d156cc-3c62-4ab...|   REPORT_VIEW|
# +------+-------+-----------+--------------------+--------------+
#
# 87b629d1-40e9-40d2-97a5-d50cb706b280
# +----+--------------------+-----+--------------------+--------------+
# |  id|             results| term|      transaction_id|          type|
# +----+--------------------+-----+--------------------+--------------+
# |null|                null|saepe|87b629d1-40e9-40d...|        SEARCH|
# |null|[X00045, X00005, ...| null|87b629d1-40e9-40d...|SEARCH_RESULTS|
# +----+--------------------+-----+--------------------+--------------+
#
# 1b0311dd-42f5-4992-9c3a-eddeb695625d
# +------+----------------+------------+--------------------+--------------+
# |    id|         results|        term|      transaction_id|          type|
# +------+----------------+------------+--------------------+--------------+
# |  null|            null|perspiciatis|1b0311dd-42f5-499...|        SEARCH|
# |  null|[X00097, X00080]|        null|1b0311dd-42f5-499...|SEARCH_RESULTS|
# |X00080|            null|        null|1b0311dd-42f5-499...|   REPORT_VIEW|
# |X00033|            null|        null|1b0311dd-42f5-499...|   REPORT_VIEW|
# |X00080|            null|        null|1b0311dd-42f5-499...|   REPORT_VIEW|
# +------+----------------+------------+--------------------+--------------+
#
# 04b41924-0588-4b80-9f31-50e46feb003f
# +----+-------+-----+--------------------+------+
# |  id|results| term|      transaction_id|  type|
# +----+-------+-----+--------------------+------+
# |null|   null|illum|04b41924-0588-4b8...|SEARCH|
# +----+-------+-----+--------------------+------+
#
# 8ab85367-cc13-4840-a088-48403e8c3082
# +----+-------+----+--------------------+------+
# |  id|results|term|      transaction_id|  type|
# +----+-------+----+--------------------+------+
# |null|   null|fuga|8ab85367-cc13-484...|SEARCH|
# +----+-------+----+--------------------+------+
#
# 934335f6-48f8-49bb-8e76-b9f39d8671c4
# +----+--------------------+--------+--------------------+--------------+
# |  id|             results|    term|      transaction_id|          type|
# +----+--------------------+--------+--------------------+--------------+
# |null|                null|corporis|934335f6-48f8-49b...|        SEARCH|
# |null|[X00048, X00049, ...|    null|934335f6-48f8-49b...|SEARCH_RESULTS|
# +----+--------------------+--------+--------------------+--------------+
#
# 3e14250b-290f-4e78-a7d3-af85431df886
# +----+----------------+-------+--------------------+--------------+
# |  id|         results|   term|      transaction_id|          type|
# +----+----------------+-------+--------------------+--------------+
# |null|            null|ratione|3e14250b-290f-4e7...|        SEARCH|
# |null|[X00076, X00095]|   null|3e14250b-290f-4e7...|SEARCH_RESULTS|
# +----+----------------+-------+--------------------+--------------+
#
# 79acd2c0-adc8-40bc-957e-9bbf3e8c1e7c
# +----+-------+----------+--------------------+------+
# |  id|results|      term|      transaction_id|  type|
# +----+-------+----------+--------------------+------+
# |null|   null|asperiores|79acd2c0-adc8-40b...|SEARCH|
# +----+-------+----------+--------------------+------+
#
# 43b5a8fd-a387-427a-a66c-39951c887364
# +------+----------------+---------+--------------------+--------------+
# |    id|         results|     term|      transaction_id|          type|
# +------+----------------+---------+--------------------+--------------+
# |  null|            null|explicabo|43b5a8fd-a387-427...|        SEARCH|
# |  null|[X00047, X00010]|     null|43b5a8fd-a387-427...|SEARCH_RESULTS|
# |X00014|            null|     null|43b5a8fd-a387-427...|   REPORT_VIEW|
# +------+----------------+---------+--------------------+--------------+
#
# c95fc4e2-d846-4112-b9fd-942103f609ef
# +----+-------+-------+--------------------+------+
# |  id|results|   term|      transaction_id|  type|
# +----+-------+-------+--------------------+------+
# |null|   null|aperiam|c95fc4e2-d846-411...|SEARCH|
# +----+-------+-------+--------------------+------+
#
# bd0b444c-36de-4a41-ad23-cda68d3e9ed7
# +----+-------+----+--------------------+------+
# |  id|results|term|      transaction_id|  type|
# +----+-------+----+--------------------+------+
# |null|   null|quis|bd0b444c-36de-4a4...|SEARCH|
# +----+-------+----+--------------------+------+
#
# e5d82238-530d-4467-97a7-d3e6e58bc095
# +----+-------+----+--------------------+--------------+
# |  id|results|term|      transaction_id|          type|
# +----+-------+----+--------------------+--------------+
# |null|   null| sit|e5d82238-530d-446...|        SEARCH|
# |null|     []|null|e5d82238-530d-446...|SEARCH_RESULTS|
# +----+-------+----+--------------------+--------------+
#
# 5c48126d-331d-4023-bf97-8f8bc0820b95
# +----+-------+----+--------------------+------+
# |  id|results|term|      transaction_id|  type|
# +----+-------+----+--------------------+------+
# |null|   null| aut|5c48126d-331d-402...|SEARCH|
# +----+-------+----+--------------------+------+
#
# 3a8e7800-a17c-4c9b-94b2-26c9e3f6fcba
# +----+----------------+--------+--------------------+--------------+
# |  id|         results|    term|      transaction_id|          type|
# +----+----------------+--------+--------------------+--------------+
# |null|            null|deleniti|3a8e7800-a17c-4c9...|        SEARCH|
# |null|[X00050, X00089]|    null|3a8e7800-a17c-4c9...|SEARCH_RESULTS|
# +----+----------------+--------+--------------------+--------------+
#
# 4bbda72c-896f-4e72-aaf0-3c87ff95f200
# +------+--------+------+--------------------+--------------+
# |    id| results|  term|      transaction_id|          type|
# +------+--------+------+--------------------+--------------+
# |  null|    null|quidem|4bbda72c-896f-4e7...|        SEARCH|
# |  null|[X00004]|  null|4bbda72c-896f-4e7...|SEARCH_RESULTS|
# |X00004|    null|  null|4bbda72c-896f-4e7...|   REPORT_VIEW|
# |X00014|    null|  null|4bbda72c-896f-4e7...|   REPORT_VIEW|
# +------+--------+------+--------------------+--------------+
#
# 2de0eb56-79b2-4a7a-8399-4339b7709905
# +----+--------------------+---------+--------------------+--------------+
# |  id|             results|     term|      transaction_id|          type|
# +----+--------------------+---------+--------------------+--------------+
# |null|                null|voluptate|2de0eb56-79b2-4a7...|        SEARCH|
# |null|[X00089, X00002, ...|     null|2de0eb56-79b2-4a7...|SEARCH_RESULTS|
# +----+--------------------+---------+--------------------+--------------+
#
# bfafa848-bccf-4041-8022-5beef47e6a3b
# +------+----------------+--------+--------------------+--------------+
# |    id|         results|    term|      transaction_id|          type|
# +------+----------------+--------+--------------------+--------------+
# |  null|            null|nesciunt|bfafa848-bccf-404...|        SEARCH|
# |  null|[X00068, X00066]|    null|bfafa848-bccf-404...|SEARCH_RESULTS|
# |X00066|            null|    null|bfafa848-bccf-404...|   REPORT_VIEW|
# +------+----------------+--------+--------------------+--------------+
#
# c45ad32c-9a70-4da9-a662-9056e7f80242
# +------+--------------------+---------+--------------------+--------------+
# |    id|             results|     term|      transaction_id|          type|
# +------+--------------------+---------+--------------------+--------------+
# |  null|                null|explicabo|c45ad32c-9a70-4da...|        SEARCH|
# |  null|[X00098, X00040, ...|     null|c45ad32c-9a70-4da...|SEARCH_RESULTS|
# |X00033|                null|     null|c45ad32c-9a70-4da...|   REPORT_VIEW|
# |X00033|                null|     null|c45ad32c-9a70-4da...|   REPORT_VIEW|
# +------+--------------------+---------+--------------------+--------------+
#
# 96fccdf5-353e-4186-9a99-72ea46d5137a
# +------+--------+----+--------------------+--------------+
# |    id| results|term|      transaction_id|          type|
# +------+--------+----+--------------------+--------------+
# |  null|    null|illo|96fccdf5-353e-418...|        SEARCH|
# |  null|[X00054]|null|96fccdf5-353e-418...|SEARCH_RESULTS|
# |X00054|    null|null|96fccdf5-353e-418...|   REPORT_VIEW|
# |X00033|    null|null|96fccdf5-353e-418...|   REPORT_VIEW|
# |X00054|    null|null|96fccdf5-353e-418...|   REPORT_VIEW|
# +------+--------+----+--------------------+--------------+
#
# 1aec047d-f84f-42c8-913f-147506d0cde0
# +------+--------------------+----+--------------------+--------------+
# |    id|             results|term|      transaction_id|          type|
# +------+--------------------+----+--------------------+--------------+
# |  null|                null| rem|1aec047d-f84f-42c...|        SEARCH|
# |  null|[X00026, X00070, ...|null|1aec047d-f84f-42c...|SEARCH_RESULTS|
# |X00050|                null|null|1aec047d-f84f-42c...|   REPORT_VIEW|
# |X00020|                null|null|1aec047d-f84f-42c...|   REPORT_VIEW|
# +------+--------------------+----+--------------------+--------------+
#
# 4b718ecb-bd05-4a41-b17e-9bbf9a8a3786
# +----+-------+----+--------------------+------+
# |  id|results|term|      transaction_id|  type|
# +----+-------+----+--------------------+------+
# |null|   null| rem|4b718ecb-bd05-4a4...|SEARCH|
# +----+-------+----+--------------------+------+
#
# ca41ceaf-0c94-449f-9c87-36025efe2f1b
# +----+-------+----+--------------------+------+
# |  id|results|term|      transaction_id|  type|
# +----+-------+----+--------------------+------+
# |null|   null| vel|ca41ceaf-0c94-449...|SEARCH|
# +----+-------+----+--------------------+------+
#
# e3d010eb-3054-4d1b-9c0f-2df38a34c653
# +----+--------+-----+--------------------+--------------+
# |  id| results| term|      transaction_id|          type|
# +----+--------+-----+--------------------+--------------+
# |null|    null|natus|e3d010eb-3054-4d1...|        SEARCH|
# |null|[X00076]| null|e3d010eb-3054-4d1...|SEARCH_RESULTS|
# +----+--------+-----+--------------------+--------------+
#
# c912bc26-9068-4f3c-b29c-cea830871abe
# +------+--------------------+----------+--------------------+--------------+
# |    id|             results|      term|      transaction_id|          type|
# +------+--------------------+----------+--------------------+--------------+
# |  null|                null|reiciendis|c912bc26-9068-4f3...|        SEARCH|
# |  null|[X00099, X00059, ...|      null|c912bc26-9068-4f3...|SEARCH_RESULTS|
# |X00019|                null|      null|c912bc26-9068-4f3...|   REPORT_VIEW|
# |X00014|                null|      null|c912bc26-9068-4f3...|   REPORT_VIEW|
# +------+--------------------+----------+--------------------+--------------+
#
# 89118d14-a6f3-42e9-a089-f688c4a0ed94
# +----+--------------------+----+--------------------+--------------+
# |  id|             results|term|      transaction_id|          type|
# +----+--------------------+----+--------------------+--------------+
# |null|                null| eos|89118d14-a6f3-42e...|        SEARCH|
# |null|[X00048, X00083, ...|null|89118d14-a6f3-42e...|SEARCH_RESULTS|
# +----+--------------------+----+--------------------+--------------+
#
# 03a7e755-47fe-4276-b93e-029d0bc55034
# +------+--------------------+--------+--------------------+--------------+
# |    id|             results|    term|      transaction_id|          type|
# +------+--------------------+--------+--------------------+--------------+
# |  null|                null|possimus|03a7e755-47fe-427...|        SEARCH|
# |  null|[X00063, X00098, ...|    null|03a7e755-47fe-427...|SEARCH_RESULTS|
# |X00063|                null|    null|03a7e755-47fe-427...|   REPORT_VIEW|
# |X00063|                null|    null|03a7e755-47fe-427...|   REPORT_VIEW|
# |X00063|                null|    null|03a7e755-47fe-427...|   REPORT_VIEW|
# +------+--------------------+--------+--------------------+--------------+
#
# 258df130-11fe-4881-88b9-04bba92df2e1
# +----+-------+--------+--------------------+------+
# |  id|results|    term|      transaction_id|  type|
# +----+-------+--------+--------------------+------+
# |null|   null|suscipit|258df130-11fe-488...|SEARCH|
# +----+-------+--------+--------------------+------+
#
# 24a69766-de30-403a-a84f-d595d9c2149f
# +------+-------+----+--------------------+--------------+
# |    id|results|term|      transaction_id|          type|
# +------+-------+----+--------------------+--------------+
# |  null|   null|fuga|24a69766-de30-403...|        SEARCH|
# |  null|     []|null|24a69766-de30-403...|SEARCH_RESULTS|
# |X00092|   null|null|24a69766-de30-403...|   REPORT_VIEW|
# |X00043|   null|null|24a69766-de30-403...|   REPORT_VIEW|
# |X00069|   null|null|24a69766-de30-403...|   REPORT_VIEW|
# +------+-------+----+--------------------+--------------+
#
# e33261fc-8513-49dc-b62c-baebaa5bb2a9
# +------+-------+----+--------------------+--------------+
# |    id|results|term|      transaction_id|          type|
# +------+-------+----+--------------------+--------------+
# |  null|   null| aut|e33261fc-8513-49d...|        SEARCH|
# |  null|     []|null|e33261fc-8513-49d...|SEARCH_RESULTS|
# |X00015|   null|null|e33261fc-8513-49d...|   REPORT_VIEW|
# |X00043|   null|null|e33261fc-8513-49d...|   REPORT_VIEW|
# +------+-------+----+--------------------+--------------+
#
# a9d68c0a-0257-40d9-b8c2-acb3971df226
# +----+--------------------+--------------+--------------------+--------------+
# |  id|             results|          term|      transaction_id|          type|
# +----+--------------------+--------------+--------------------+--------------+
# |null|                null|necessitatibus|a9d68c0a-0257-40d...|        SEARCH|
# |null|[X00008, X00096, ...|          null|a9d68c0a-0257-40d...|SEARCH_RESULTS|
# +----+--------------------+--------------+--------------------+--------------+
#
# e3a644c8-924e-473b-991b-151438e8cd7b
# +----+-------+-------+--------------------+------+
# |  id|results|   term|      transaction_id|  type|
# +----+-------+-------+--------------------+------+
# |null|   null|quaerat|e3a644c8-924e-473...|SEARCH|
# +----+-------+-------+--------------------+------+
#
# 4f0bbf4d-eb8e-4e50-9eda-79add2c184d1
# +----+-------+---------+--------------------+------+
# |  id|results|     term|      transaction_id|  type|
# +----+-------+---------+--------------------+------+
# |null|   null|explicabo|4f0bbf4d-eb8e-4e5...|SEARCH|
# +----+-------+---------+--------------------+------+
#
# 12296872-a481-40b0-815b-06f707e9c7b2
# +----+-------+-----+--------------------+--------------+
# |  id|results| term|      transaction_id|          type|
# +----+-------+-----+--------------------+--------------+
# |null|   null|minus|12296872-a481-40b...|        SEARCH|
# |null|     []| null|12296872-a481-40b...|SEARCH_RESULTS|
# +----+-------+-----+--------------------+--------------+
#
# 2dfefa7a-daa4-48c4-88d9-c914e4575c8a
# +----+-------+-----------+--------------------+--------------+
# |  id|results|       term|      transaction_id|          type|
# +----+-------+-----------+--------------------+--------------+
# |null|   null|dignissimos|2dfefa7a-daa4-48c...|        SEARCH|
# |null|     []|       null|2dfefa7a-daa4-48c...|SEARCH_RESULTS|
# +----+-------+-----------+--------------------+--------------+
#
# a098cefa-e62a-44da-8c7d-526d33ec17de
# +------+--------+-------+--------------------+--------------+
# |    id| results|   term|      transaction_id|          type|
# +------+--------+-------+--------------------+--------------+
# |  null|    null|tenetur|a098cefa-e62a-44d...|        SEARCH|
# |  null|[X00006]|   null|a098cefa-e62a-44d...|SEARCH_RESULTS|
# |X00006|    null|   null|a098cefa-e62a-44d...|   REPORT_VIEW|
# |X00081|    null|   null|a098cefa-e62a-44d...|   REPORT_VIEW|
# +------+--------+-------+--------------------+--------------+
#
# c5b9a479-662b-4a6e-8208-949c984e4d57
# +------+----------------+----------+--------------------+--------------+
# |    id|         results|      term|      transaction_id|          type|
# +------+----------------+----------+--------------------+--------------+
# |  null|            null|architecto|c5b9a479-662b-4a6...|        SEARCH|
# |  null|[X00094, X00069]|      null|c5b9a479-662b-4a6...|SEARCH_RESULTS|
# |X00094|            null|      null|c5b9a479-662b-4a6...|   REPORT_VIEW|
# |X00069|            null|      null|c5b9a479-662b-4a6...|   REPORT_VIEW|
# |X00069|            null|      null|c5b9a479-662b-4a6...|   REPORT_VIEW|
# +------+----------------+----------+--------------------+--------------+
#
# f7580ce2-c582-4300-8057-dbe71d0f9bee
# +----+-------+----+--------------------+------+
# |  id|results|term|      transaction_id|  type|
# +----+-------+----+--------------------+------+
# |null|   null|quis|f7580ce2-c582-430...|SEARCH|
# +----+-------+----+--------------------+------+
#
# 3d295683-25b0-423c-b63c-1bea28327624
# +----+-------+----+--------------------+------+
# |  id|results|term|      transaction_id|  type|
# +----+-------+----+--------------------+------+
# |null|   null| vel|3d295683-25b0-423...|SEARCH|
# +----+-------+----+--------------------+------+
#
# 7ff3af3b-16a5-43e2-8960-82705000e414
# +----+-------+-------+--------------------+------+
# |  id|results|   term|      transaction_id|  type|
# +----+-------+-------+--------------------+------+
# |null|   null|quaerat|7ff3af3b-16a5-43e...|SEARCH|
# +----+-------+-------+--------------------+------+
#
# e9208381-3942-4086-93c5-8bedc0b7b21d
# +----+-------+-----------+--------------------+------+
# |  id|results|       term|      transaction_id|  type|
# +----+-------+-----------+--------------------+------+
# |null|   null|consectetur|e9208381-3942-408...|SEARCH|
# +----+-------+-----------+--------------------+------+
#
# fd627b23-fa3d-446e-8d4c-9b64be170f09
# +------+--------+-----+--------------------+--------------+
# |    id| results| term|      transaction_id|          type|
# +------+--------+-----+--------------------+--------------+
# |  null|    null|autem|fd627b23-fa3d-446...|        SEARCH|
# |  null|[X00045]| null|fd627b23-fa3d-446...|SEARCH_RESULTS|
# |X00045|    null| null|fd627b23-fa3d-446...|   REPORT_VIEW|
# |X00045|    null| null|fd627b23-fa3d-446...|   REPORT_VIEW|
# |X00045|    null| null|fd627b23-fa3d-446...|   REPORT_VIEW|
# +------+--------+-----+--------------------+--------------+
#
# ef7049e8-7471-4b5a-8591-5a95149a446a
# +----+--------------------+----+--------------------+--------------+
# |  id|             results|term|      transaction_id|          type|
# +----+--------------------+----+--------------------+--------------+
# |null|                null|quas|ef7049e8-7471-4b5...|        SEARCH|
# |null|[X00015, X00082, ...|null|ef7049e8-7471-4b5...|SEARCH_RESULTS|
# +----+--------------------+----+--------------------+--------------+
#
# 5ba12c65-c4d9-43c6-b322-7d2f346b86a7
# +------+--------------------+-----------+--------------------+--------------+
# |    id|             results|       term|      transaction_id|          type|
# +------+--------------------+-----------+--------------------+--------------+
# |  null|                null|consectetur|5ba12c65-c4d9-43c...|        SEARCH|
# |  null|[X00078, X00065, ...|       null|5ba12c65-c4d9-43c...|SEARCH_RESULTS|
# |X00054|                null|       null|5ba12c65-c4d9-43c...|   REPORT_VIEW|
# |X00078|                null|       null|5ba12c65-c4d9-43c...|   REPORT_VIEW|
# +------+--------------------+-----------+--------------------+--------------+
#
# fb4e4662-be66-45ef-bb18-509a80795fa8
# +------+--------------------+----+--------------------+--------------+
# |    id|             results|term|      transaction_id|          type|
# +------+--------------------+----+--------------------+--------------+
# |  null|                null|odio|fb4e4662-be66-45e...|        SEARCH|
# |  null|[X00045, X00036, ...|null|fb4e4662-be66-45e...|SEARCH_RESULTS|
# |X00036|                null|null|fb4e4662-be66-45e...|   REPORT_VIEW|
# |X00090|                null|null|fb4e4662-be66-45e...|   REPORT_VIEW|
# +------+--------------------+----+--------------------+--------------+
#
# 30b823a7-e20b-42ed-a21b-decba5f24e3c
# +----+--------------------+----------+--------------------+--------------+
# |  id|             results|      term|      transaction_id|          type|
# +----+--------------------+----------+--------------------+--------------+
# |null|                null|aspernatur|30b823a7-e20b-42e...|        SEARCH|
# |null|[X00018, X00033, ...|      null|30b823a7-e20b-42e...|SEARCH_RESULTS|
# +----+--------------------+----------+--------------------+--------------+
#
# 5c03293e-a8a3-46ba-a468-5919861aeda4
# +------+-------+---------+--------------------+--------------+
# |    id|results|     term|      transaction_id|          type|
# +------+-------+---------+--------------------+--------------+
# |  null|   null|molestias|5c03293e-a8a3-46b...|        SEARCH|
# |  null|     []|     null|5c03293e-a8a3-46b...|SEARCH_RESULTS|
# |X00096|   null|     null|5c03293e-a8a3-46b...|   REPORT_VIEW|
# +------+-------+---------+--------------------+--------------+
#
# 7cd30f79-7a3f-46f7-9554-d98546833941
# +----+----------------+--------+--------------------+--------------+
# |  id|         results|    term|      transaction_id|          type|
# +----+----------------+--------+--------------------+--------------+
# |null|            null|eligendi|7cd30f79-7a3f-46f...|        SEARCH|
# |null|[X00028, X00059]|    null|7cd30f79-7a3f-46f...|SEARCH_RESULTS|
# +----+----------------+--------+--------------------+--------------+
#
# 84acd12b-3b47-4c42-adf7-5c51074fa4da
# +----+-------+-------+--------------------+------+
# |  id|results|   term|      transaction_id|  type|
# +----+-------+-------+--------------------+------+
# |null|   null|tempora|84acd12b-3b47-4c4...|SEARCH|
# +----+-------+-------+--------------------+------+
#
# 97e64c9e-4510-4a19-9cae-bb16a0340daa
# +----+-------+----+--------------------+--------------+
# |  id|results|term|      transaction_id|          type|
# +----+-------+----+--------------------+--------------+
# |null|   null| rem|97e64c9e-4510-4a1...|        SEARCH|
# |null|     []|null|97e64c9e-4510-4a1...|SEARCH_RESULTS|
# +----+-------+----+--------------------+--------------+
#
# 27bfa202-67a8-4f36-80a8-0334792b57b3
# +------+--------+----------+--------------------+--------------+
# |    id| results|      term|      transaction_id|          type|
# +------+--------+----------+--------------------+--------------+
# |  null|    null|voluptatum|27bfa202-67a8-4f3...|        SEARCH|
# |  null|[X00090]|      null|27bfa202-67a8-4f3...|SEARCH_RESULTS|
# |X00043|    null|      null|27bfa202-67a8-4f3...|   REPORT_VIEW|
# |X00090|    null|      null|27bfa202-67a8-4f3...|   REPORT_VIEW|
# +------+--------+----------+--------------------+--------------+
#
# bfcf8f78-3032-4848-92a0-0b4cd33677d1
# +------+--------------------+----+--------------------+--------------+
# |    id|             results|term|      transaction_id|          type|
# +------+--------------------+----+--------------------+--------------+
# |  null|                null| eos|bfcf8f78-3032-484...|        SEARCH|
# |  null|[X00078, X00013, ...|null|bfcf8f78-3032-484...|SEARCH_RESULTS|
# |X00013|                null|null|bfcf8f78-3032-484...|   REPORT_VIEW|
# +------+--------------------+----+--------------------+--------------+
#
# 42be1635-bc07-492f-a931-7a1568cf607e
# +----+-------+----+--------------------+------+
# |  id|results|term|      transaction_id|  type|
# +----+-------+----+--------------------+------+
# |null|   null| non|42be1635-bc07-492...|SEARCH|
# +----+-------+----+--------------------+------+
#
# 1c4e8fad-31b1-4d9e-805c-d670b7b6f62a
# +------+--------+----+--------------------+--------------+
# |    id| results|term|      transaction_id|          type|
# +------+--------+----+--------------------+--------------+
# |  null|    null|  id|1c4e8fad-31b1-4d9...|        SEARCH|
# |  null|[X00061]|null|1c4e8fad-31b1-4d9...|SEARCH_RESULTS|
# |X00061|    null|null|1c4e8fad-31b1-4d9...|   REPORT_VIEW|
# |X00085|    null|null|1c4e8fad-31b1-4d9...|   REPORT_VIEW|
# |X00087|    null|null|1c4e8fad-31b1-4d9...|   REPORT_VIEW|
# +------+--------+----+--------------------+--------------+
#
# 76bfbc17-8db7-480d-94af-c761293016df
# +----+-------+-------+--------------------+------+
# |  id|results|   term|      transaction_id|  type|
# +----+-------+-------+--------------------+------+
# |null|   null|aperiam|76bfbc17-8db7-480...|SEARCH|
# +----+-------+-------+--------------------+------+
#
# 6ae941c9-39f5-4907-841c-60e3ae1e4298
# +------+----------------+--------+--------------------+--------------+
# |    id|         results|    term|      transaction_id|          type|
# +------+----------------+--------+--------------------+--------------+
# |  null|            null|incidunt|6ae941c9-39f5-490...|        SEARCH|
# |  null|[X00091, X00085]|    null|6ae941c9-39f5-490...|SEARCH_RESULTS|
# |X00085|            null|    null|6ae941c9-39f5-490...|   REPORT_VIEW|
# +------+----------------+--------+--------------------+--------------+
#
# 8b5b1935-332e-412a-b645-768a51555741
# +----+-------+----------+--------------------+------+
# |  id|results|      term|      transaction_id|  type|
# +----+-------+----------+--------------------+------+
# |null|   null|recusandae|8b5b1935-332e-412...|SEARCH|
# +----+-------+----------+--------------------+------+
#
# 33addc89-ea16-4ca6-b155-d2c4c962a701
# +----+----------------+----+--------------------+--------------+
# |  id|         results|term|      transaction_id|          type|
# +----+----------------+----+--------------------+--------------+
# |null|            null|unde|33addc89-ea16-4ca...|        SEARCH|
# |null|[X00082, X00019]|null|33addc89-ea16-4ca...|SEARCH_RESULTS|
# +----+----------------+----+--------------------+--------------+
#
# 54d1b4d2-8319-43d6-885c-cfddc7c8c466
# +----+-------+----+--------------------+------+
# |  id|results|term|      transaction_id|  type|
# +----+-------+----+--------------------+------+
# |null|   null| non|54d1b4d2-8319-43d...|SEARCH|
# +----+-------+----+--------------------+------+
#
# 71dbb0b7-4c68-4b9c-b4e1-7fd4d0f753e1
# +------+--------------------+----+--------------------+--------------+
# |    id|             results|term|      transaction_id|          type|
# +------+--------------------+----+--------------------+--------------+
# |  null|                null|fuga|71dbb0b7-4c68-4b9...|        SEARCH|
# |  null|[X00065, X00007, ...|null|71dbb0b7-4c68-4b9...|SEARCH_RESULTS|
# |X00050|                null|null|71dbb0b7-4c68-4b9...|   REPORT_VIEW|
# |X00007|                null|null|71dbb0b7-4c68-4b9...|   REPORT_VIEW|
# +------+--------------------+----+--------------------+--------------+
#
# 374ae590-3af2-4479-8a49-14bc7b876af5
# +----+-------+----------+--------------------+--------------+
# |  id|results|      term|      transaction_id|          type|
# +----+-------+----------+--------------------+--------------+
# |null|   null|voluptates|374ae590-3af2-447...|        SEARCH|
# |null|     []|      null|374ae590-3af2-447...|SEARCH_RESULTS|
# +----+-------+----------+--------------------+--------------+
#
# dea6b699-dc1a-4131-9497-d284bb34070c
# +----+-------+-----+--------------------+------+
# |  id|results| term|      transaction_id|  type|
# +----+-------+-----+--------------------+------+
# |null|   null|dolor|dea6b699-dc1a-413...|SEARCH|
# +----+-------+-----+--------------------+------+
#
# 35c1643d-eb0e-470a-8a2f-9999939568a5
# +----+-------+-------+--------------------+------+
# |  id|results|   term|      transaction_id|  type|
# +----+-------+-------+--------------------+------+
# |null|   null|laborum|35c1643d-eb0e-470...|SEARCH|
# +----+-------+-------+--------------------+------+
#
# caa4e9a9-635d-4c90-88c6-d911c004e071
# +----+--------------------+----+--------------------+--------------+
# |  id|             results|term|      transaction_id|          type|
# +----+--------------------+----+--------------------+--------------+
# |null|                null| est|caa4e9a9-635d-4c9...|        SEARCH|
# |null|[X00033, X00068, ...|null|caa4e9a9-635d-4c9...|SEARCH_RESULTS|
# +----+--------------------+----+--------------------+--------------+
#
# 9bf8ae8b-8474-4894-97a4-e7df4e254954
# +------+--------------------+--------+--------------------+--------------+
# |    id|             results|    term|      transaction_id|          type|
# +------+--------------------+--------+--------------------+--------------+
# |  null|                null|repellat|9bf8ae8b-8474-489...|        SEARCH|
# |  null|[X00031, X00098, ...|    null|9bf8ae8b-8474-489...|SEARCH_RESULTS|
# |X00098|                null|    null|9bf8ae8b-8474-489...|   REPORT_VIEW|
# |X00098|                null|    null|9bf8ae8b-8474-489...|   REPORT_VIEW|
# |X00025|                null|    null|9bf8ae8b-8474-489...|   REPORT_VIEW|
# +------+--------------------+--------+--------------------+--------------+
#
# a57146ce-d05f-4d2b-85cd-ea5f962f2022
# +------+-------+----+--------------------+--------------+
# |    id|results|term|      transaction_id|          type|
# +------+-------+----+--------------------+--------------+
# |  null|   null| non|a57146ce-d05f-4d2...|        SEARCH|
# |  null|     []|null|a57146ce-d05f-4d2...|SEARCH_RESULTS|
# |X00017|   null|null|a57146ce-d05f-4d2...|   REPORT_VIEW|
# |X00012|   null|null|a57146ce-d05f-4d2...|   REPORT_VIEW|
# |X00063|   null|null|a57146ce-d05f-4d2...|   REPORT_VIEW|
# +------+-------+----+--------------------+--------------+
#
# ff200ccf-5089-43e8-b048-5277d2cc3385
# +----+-------+-------+--------------------+------+
# |  id|results|   term|      transaction_id|  type|
# +----+-------+-------+--------------------+------+
# |null|   null|dolorum|ff200ccf-5089-43e...|SEARCH|
# +----+-------+-------+--------------------+------+
#
# 141a59dd-6c8a-49c3-a9fc-7c3a8295b8f5
# +----+-------+----+--------------------+------+
# |  id|results|term|      transaction_id|  type|
# +----+-------+----+--------------------+------+
# |null|   null|quam|141a59dd-6c8a-49c...|SEARCH|
# +----+-------+----+--------------------+------+
#
# a6698463-c7ad-431e-90c5-80585a831b1f
# +----+--------------------+-----+--------------------+--------------+
# |  id|             results| term|      transaction_id|          type|
# +----+--------------------+-----+--------------------+--------------+
# |null|                null|nobis|a6698463-c7ad-431...|        SEARCH|
# |null|[X00001, X00046, ...| null|a6698463-c7ad-431...|SEARCH_RESULTS|
# +----+--------------------+-----+--------------------+--------------+
#
# 305a95da-c4c0-486f-a1df-03ed994fc69a
# +------+--------------------+------+--------------------+--------------+
# |    id|             results|  term|      transaction_id|          type|
# +------+--------------------+------+--------------------+--------------+
# |  null|                null|libero|305a95da-c4c0-486...|        SEARCH|
# |  null|[X00071, X00088, ...|  null|305a95da-c4c0-486...|SEARCH_RESULTS|
# |X00088|                null|  null|305a95da-c4c0-486...|   REPORT_VIEW|
# |X00060|                null|  null|305a95da-c4c0-486...|   REPORT_VIEW|
# +------+--------------------+------+--------------------+--------------+
#
# 36a729eb-e4f7-4976-ace2-491a8cec4e30
# +------+--------+-----+--------------------+--------------+
# |    id| results| term|      transaction_id|          type|
# +------+--------+-----+--------------------+--------------+
# |  null|    null|sequi|36a729eb-e4f7-497...|        SEARCH|
# |  null|[X00052]| null|36a729eb-e4f7-497...|SEARCH_RESULTS|
# |X00052|    null| null|36a729eb-e4f7-497...|   REPORT_VIEW|
# |X00052|    null| null|36a729eb-e4f7-497...|   REPORT_VIEW|
# +------+--------+-----+--------------------+--------------+
#
# 9b82a1ef-32b4-4e29-9bea-796b5d38177d
# +----+--------+----+--------------------+--------------+
# |  id| results|term|      transaction_id|          type|
# +----+--------+----+--------------------+--------------+
# |null|    null| sit|9b82a1ef-32b4-4e2...|        SEARCH|
# |null|[X00071]|null|9b82a1ef-32b4-4e2...|SEARCH_RESULTS|
# +----+--------+----+--------------------+--------------+
#
# 8f2430d0-4e8c-41c0-8b9d-20911f9ddb21
# +----+-------+----------+--------------------+------+
# |  id|results|      term|      transaction_id|  type|
# +----+-------+----------+--------------------+------+
# |null|   null|reiciendis|8f2430d0-4e8c-41c...|SEARCH|
# +----+-------+----------+--------------------+------+
#
# 9520c045-635e-4a92-84db-996ec9b31e58
# +----+-------+--------+--------------------+--------------+
# |  id|results|    term|      transaction_id|          type|
# +----+-------+--------+--------------------+--------------+
# |null|   null|quisquam|9520c045-635e-4a9...|        SEARCH|
# |null|     []|    null|9520c045-635e-4a9...|SEARCH_RESULTS|
# +----+-------+--------+--------------------+--------------+
#
# 0e5c2bc1-7917-4a79-8e4d-00b59781617d
# +------+----------------+----+--------------------+--------------+
# |    id|         results|term|      transaction_id|          type|
# +------+----------------+----+--------------------+--------------+
# |  null|            null|quae|0e5c2bc1-7917-4a7...|        SEARCH|
# |  null|[X00047, X00016]|null|0e5c2bc1-7917-4a7...|SEARCH_RESULTS|
# |X00047|            null|null|0e5c2bc1-7917-4a7...|   REPORT_VIEW|
# +------+----------------+----+--------------------+--------------+
#
# cc6192bb-525e-4a7c-b10a-db9b24f311c9
# +------+-------+-------+--------------------+--------------+
# |    id|results|   term|      transaction_id|          type|
# +------+-------+-------+--------------------+--------------+
# |  null|   null|aliquid|cc6192bb-525e-4a7...|        SEARCH|
# |  null|     []|   null|cc6192bb-525e-4a7...|SEARCH_RESULTS|
# |X00024|   null|   null|cc6192bb-525e-4a7...|   REPORT_VIEW|
# +------+-------+-------+--------------------+--------------+
#
# 2732ae22-888d-4be8-8c3e-020da3e323a5
# +----+----------------+------------+--------------------+--------------+
# |  id|         results|        term|      transaction_id|          type|
# +----+----------------+------------+--------------------+--------------+
# |null|            null|perspiciatis|2732ae22-888d-4be...|        SEARCH|
# |null|[X00018, X00058]|        null|2732ae22-888d-4be...|SEARCH_RESULTS|
# +----+----------------+------------+--------------------+--------------+
#
# 4305a0aa-6a4f-4cec-b4ab-cefdbc1e0f9c
# +------+--------------------+-------+--------------------+--------------+
# |    id|             results|   term|      transaction_id|          type|
# +------+--------------------+-------+--------------------+--------------+
# |  null|                null|facilis|4305a0aa-6a4f-4ce...|        SEARCH|
# |  null|[X00061, X00026, ...|   null|4305a0aa-6a4f-4ce...|SEARCH_RESULTS|
# |X00061|                null|   null|4305a0aa-6a4f-4ce...|   REPORT_VIEW|
# +------+--------------------+-------+--------------------+--------------+
#
# 8b34dc05-b947-4433-a733-b71eed9ed0b1
# +----+-------+----+--------------------+------+
# |  id|results|term|      transaction_id|  type|
# +----+-------+----+--------------------+------+
# |null|   null|eius|8b34dc05-b947-443...|SEARCH|
# +----+-------+----+--------------------+------+
#
# 730e4524-bc6b-4068-869a-5194ff9e4c2d
# +----+-------+-------+--------------------+------+
# |  id|results|   term|      transaction_id|  type|
# +----+-------+-------+--------------------+------+
# |null|   null|ratione|730e4524-bc6b-406...|SEARCH|
# +----+-------+-------+--------------------+------+
