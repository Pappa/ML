# %%
from pyspark.sql.types import StructType, StructField, StringType, ArrayType, Row
from functools import reduce

# %%
filename = './test_data/events.json'

df = spark.read.option("multiline","true").json(filename)
df.printSchema()
df.show()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- results: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- term: string (nullable = true)
#  |-- transaction_id: string (nullable = true)
#  |-- type: string (nullable = true)
#
# +------+--------------------+-----------+--------------------+--------------+
# |    id|             results|       term|      transaction_id|          type|
# +------+--------------------+-----------+--------------------+--------------+
# |  null|                null|      omnis|9e4bdbef-86fe-4ac...|        SEARCH|
# |  null|[X00034, X00084, ...|       null|9e4bdbef-86fe-4ac...|SEARCH_RESULTS|
# |X00022|                null|       null|9e4bdbef-86fe-4ac...|   REPORT_VIEW|
# |X00084|                null|       null|9e4bdbef-86fe-4ac...|   REPORT_VIEW|
# |  null|                null|      quasi|067bf59a-2f53-459...|        SEARCH|
# |  null|[X00042, X00031, ...|       null|067bf59a-2f53-459...|SEARCH_RESULTS|
# |  null|                null|   sapiente|e0bf0ee2-3b0a-409...|        SEARCH|
# |  null|                  []|       null|e0bf0ee2-3b0a-409...|SEARCH_RESULTS|
# |  null|                null|  molestias|507e386e-d29a-406...|        SEARCH|
# |  null|            [X00097]|       null|507e386e-d29a-406...|SEARCH_RESULTS|
# |  null|                null|         ex|029c1fe7-722a-45f...|        SEARCH|
# |  null|                null|      porro|f92a19c9-7918-40b...|        SEARCH|
# |  null|[X00087, X00030, ...|       null|f92a19c9-7918-40b...|SEARCH_RESULTS|
# |  null|                null|     libero|6d030326-b720-433...|        SEARCH|
# |  null|                null|         ad|418ee440-d224-4d8...|        SEARCH|
# |  null|    [X00036, X00044]|       null|418ee440-d224-4d8...|SEARCH_RESULTS|
# |  null|                null|repellendus|3344a027-5455-496...|        SEARCH|
# |  null|                null|         at|221a1f34-a894-443...|        SEARCH|
# |  null|    [X00027, X00030]|       null|221a1f34-a894-443...|SEARCH_RESULTS|
# |X00030|                null|       null|221a1f34-a894-443...|   REPORT_VIEW|
# +------+--------------------+-----------+--------------------+--------------+
# only showing top 20 rows

# %%
event_schema = StructType(
        [
            StructField("id", StringType(), True),
            StructField("results", ArrayType(StringType(), True), True),
            StructField("term", StringType(), True),
            StructField("transaction_id", StringType(), True),
            StructField("type", StringType(), True),
        ]
    )

group_schema = StructType(
        [
            StructField("t_id", StringType(), True),
            StructField("events", ArrayType(event_schema, True), True),
        ]
    )

# %%
grouped = df.rdd.groupBy(lambda row: row['transaction_id']) \
    .map(lambda group: group[1]) \
    .map(list)

print('grouped', type(grouped))

print('grouped.first()', type(grouped.first()))

def mapper(group):
    transaction_id = group[0]['transaction_id']
    reports_viewed = [row['id'] for row in group if row['id'] != None]
    search_results = [result for row in group if row['results'] != None for result in row['results']]
    return Row(
        transaction_id=transaction_id,
        reports_viewed=reports_viewed,
        search_results=search_results
    )

mapped = grouped.map(mapper)

res = mapped.collect()

print(type(res[0][0]))

print(res)
# Out:
# grouped <class 'pyspark.rdd.PipelinedRDD'>
# grouped.first() <class 'list'>
# <class 'str'>
# [Row(transaction_id='9e4bdbef-86fe-4ace-aa61-d29a64bbb5f4', reports_viewed=['X00022', 'X00084'], search_results=['X00034', 'X00084', 'X00009', 'X00071']), Row(transaction_id='067bf59a-2f53-459b-8ad0-2cb4a9639519', reports_viewed=[], search_results=['X00042', 'X00031', 'X00095']), Row(transaction_id='e0bf0ee2-3b0a-4095-9483-28aecd5e1437', reports_viewed=[], search_results=[]), Row(transaction_id='507e386e-d29a-4063-9621-d51dc91063cf', reports_viewed=[], search_results=['X00097']), Row(transaction_id='029c1fe7-722a-45f3-86f8-a88d57057567', reports_viewed=[], search_results=[]), Row(transaction_id='f92a19c9-7918-40b1-9cbd-0d066b115326', reports_viewed=[], search_results=['X00087', 'X00030', 'X00045']), Row(transaction_id='6d030326-b720-433c-8e96-03b7a3f3cf15', reports_viewed=[], search_results=[]), Row(transaction_id='418ee440-d224-4d88-94b6-5aa9ec28dc73', reports_viewed=[], search_results=['X00036', 'X00044']), Row(transaction_id='3344a027-5455-496d-9ec6-b149cadbe86b', reports_viewed=[], search_results=[]), Row(transaction_id='221a1f34-a894-4438-92b5-46e0b88d6217', reports_viewed=['X00030', 'X00088', 'X00027'], search_results=['X00027', 'X00030']), Row(transaction_id='93827d0b-ae5e-4e0f-8ab7-389031d37c11', reports_viewed=[], search_results=[]), Row(transaction_id='0692d85d-8699-4954-a768-dd438534101c', reports_viewed=[], search_results=[]), Row(transaction_id='fe91129b-fcc4-4529-ad1d-4151fa856730', reports_viewed=[], search_results=[]), Row(transaction_id='9f167a48-bbbc-4946-a84c-7dee9a47d6a7', reports_viewed=['X00076', 'X00055', 'X00055'], search_results=['X00073', 'X00055']), Row(transaction_id='3abc6ca7-5846-48e3-bd10-76ca1f529c56', reports_viewed=['X00009', 'X00049', 'X00030'], search_results=['X00030', 'X00021', 'X00017', 'X00045']), Row(transaction_id='d288b607-8527-4759-9b4f-c870795d1430', reports_viewed=[], search_results=['X00020']), Row(transaction_id='5806d72b-890d-49f7-8034-b4808c68e0d1', reports_viewed=[], search_results=[]), Row(transaction_id='cb418946-7d88-4da7-befc-67d3af9fc387', reports_viewed=[], search_results=['X00011', 'X00082', 'X00053', 'X00093']), Row(transaction_id='98b52599-7abc-46a3-b26b-76da28b67d8f', reports_viewed=[], search_results=[]), Row(transaction_id='6fe2b89f-efae-4f28-8691-9fab949a0550', reports_viewed=[], search_results=['X00064', 'X00026']), Row(transaction_id='ff73e725-af85-469c-a4a7-b9695edd0491', reports_viewed=[], search_results=[]), Row(transaction_id='55d156cc-3c62-4ab1-b997-415f96f0c681', reports_viewed=['X00048', 'X00030'], search_results=[]), Row(transaction_id='87b629d1-40e9-40d2-97a5-d50cb706b280', reports_viewed=[], search_results=['X00045', 'X00005', 'X00073']), Row(transaction_id='1b0311dd-42f5-4992-9c3a-eddeb695625d', reports_viewed=['X00080', 'X00033', 'X00080'], search_results=['X00097', 'X00080']), Row(transaction_id='04b41924-0588-4b80-9f31-50e46feb003f', reports_viewed=[], search_results=[]), Row(transaction_id='8ab85367-cc13-4840-a088-48403e8c3082', reports_viewed=[], search_results=[]), Row(transaction_id='934335f6-48f8-49bb-8e76-b9f39d8671c4', reports_viewed=[], search_results=['X00048', 'X00049', 'X00039', 'X00084']), Row(transaction_id='3e14250b-290f-4e78-a7d3-af85431df886', reports_viewed=[], search_results=['X00076', 'X00095']), Row(transaction_id='79acd2c0-adc8-40bc-957e-9bbf3e8c1e7c', reports_viewed=[], search_results=[]), Row(transaction_id='43b5a8fd-a387-427a-a66c-39951c887364', reports_viewed=['X00014'], search_results=['X00047', 'X00010']), Row(transaction_id='c95fc4e2-d846-4112-b9fd-942103f609ef', reports_viewed=[], search_results=[]), Row(transaction_id='bd0b444c-36de-4a41-ad23-cda68d3e9ed7', reports_viewed=[], search_results=[]), Row(transaction_id='e5d82238-530d-4467-97a7-d3e6e58bc095', reports_viewed=[], search_results=[]), Row(transaction_id='5c48126d-331d-4023-bf97-8f8bc0820b95', reports_viewed=[], search_results=[]), Row(transaction_id='3a8e7800-a17c-4c9b-94b2-26c9e3f6fcba', reports_viewed=[], search_results=['X00050', 'X00089']), Row(transaction_i ...
